# %% [markdown]
# <a href="https://colab.research.google.com/github/spino330/KursAJi/blob/main/WprowadzenieDoSrodowiska.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # podstawy Pythona
# 1.   Zmienne
# 2.   Listy
# 3.  Pętle
# 4.   Słowniki i krotki
# 5. Instrukcje warunkowe
# 6.   Funkcje
# 7.   Obsługa plików
# 8.   Obsługa wyjątków

# %%
# !git init
# !git config --global user.name "spino330"
# !git config --global user.email "piotrmomroi5@gmail.com"

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m "inicjalizacja projektu"

# %%
# !git branch  -M main

# %%
# !git push -u origin main

# %% [markdown]
# # zmienne

# %%
calkowita = 5
zmienoprzecinkowe = 6.7
napis = 'aji'
logiczna = True
print(f'całkowita {calkowita} zmienoprzecinkowe {zmienoprzecinkowe} napis  {napis} logiczna {logiczna}')
# Out:
# całkowita 5 zmienoprzecinkowe 6.7 napis  aji logiczna True

# %%
calkowita = 'butelak kaucyjna'
print(type(calkowita))
# Out:
# <class 'str'>

# %% [markdown]
# # Listy

# %%
ksiazki = ['kajko i kokosz' , 'bolek i lolek' , 'stachu jones']
lista_mieszna =  [ 1 , "dwa" , ksiazki]
print(ksiazki)
print(lista_mieszna)
print(ksiazki[1])
# Out:
# ['kajko i kokosz', 'bolek i lolek', 'stachu jones']
# [1, 'dwa', ['kajko i kokosz', 'bolek i lolek', 'stachu jones']]
# bolek i lolek

# %% [markdown]
# # Pętle

# %%
licznik  = 0

while licznik < 5:
  print(licznik)
  licznik +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for ksiazka in ksiazki:
  print(ksiazka)
# Out:
# kajko i kokosz
# bolek i lolek
# stachu jones

# %% [markdown]
# # Słowniki i krotki

# %% [markdown]
# # Instrukcje warunkowe

# %%
temperatura = float(input("Podaj temperaturę: "))

if temperatura < 20:
  print("Podwyższam temperaturę")
elif temperatura >25:
  print("Obniżam temperaturę")
else:
  print("Temperatura w normie")
# Out:
# Podaj temperaturę: 12
# Podwyższam temperaturę

# %% [markdown]
# # Funkcje

# %% [markdown]
# # Obsługa plików

# %% [markdown]
# # Obsługa wyjątków

# %%
# !git add .
# !git commit -m "nwm jakies wpropwadzenie zrobione"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# To https://github.com/spino330/KursAJi.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/spino330/KursAJi.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
